# %% [markdown]
# # Taller 3
# 1. [Función  que dada una ruta de archivo de VBox lea los datos y trabaje que con ellos.](#primero) **La función debe servir para los dos tipos de archivos VBox**.
#
# 1. [Comparar el rendimiento de combustión interna con el kart eléctrico en términos de tiempo de vuelta, velocidades instantáneas y aceleraciones, comparación y discusión.](#segundo)
#
# 1. [A partir de los modelos del taller anterior, analizar el desempeño de los motores de combustión interna y eléctrico y comparar el momento par, la potencia y la velocidad de giro.](#tercero)
#
# 1. [Sugerir posibles mejoras al kart eléctrico para acercar su desempeño al del kart de combustión interna.](#cuarto)
#
# 1. [Anexos](#quinto)

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import numpy as np
import string
import matplotlib.cm as cm
import os
from scipy import ndimage
#Carpeta para guardar las gráficas
output_dir = os.path.join( '.','output')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 1. Función para la lectura de los datos de ambos tipos de VBox <a name="primero"></a>

# %%
def load(base_dir,data_file):
    with open(os.path.join(base_dir,data_file), 'r') as vboxdata:
        section = []
        time = []
        lat = []
        long = []
        vel = []
        height = []
        vertv = []
        for line in vboxdata:
            if line[0] == '[':
                section = str.replace(line, "\n","")
                continue
            if section == '[column names]':
                col_names = str.replace(line, "  \n","").split('  ')
                section = []
            if section == '[data]':
                linesplit = str.replace(line, " \n","").split(' ')
                time.append(float(linesplit[1][0:2])*3600+float(linesplit[1][2:4])*60+float(linesplit[1][4:]))
                lat.append(float(linesplit[2]))
                long.append(float(linesplit[3]))
                vel.append(float(linesplit[4]))
                height.append(float(linesplit[6]))
                vertv.append(float(linesplit[7]))

    time = np.asarray(time)
    lat = np.asarray(lat)
    long = np.asarray(long)
    vel = np.asarray(vel)
    height = np.asarray(height)
    vertv = np.asarray(vertv)
    time_base = time[0]
    time = time - time_base
    lat = lat/60.0
    long = -long/60.0
    dt = time[1]-time[0]
    return time,lat,long,vel,height,vertv,time_base,dt

# %% [markdown]
# ## 2. Rendimiento del kart  - Tiempos, Velocidades y Aceleraciones- <a name="segundo"></a>

# %% [raw]
# La comparación de los rendimientos de cada kart se realizo tomando la forma de la curva realizadas como indice de precisión en cada dato. En la [figura 1](#fig:1) se muestran las vueltas realizadas por el kart eléctrico (en azúl), y por el kart de gasolina (en negro).

# %% [markdown]
# ###### Figura 1. Vuelta tomada para cada kart, tanto el eléctrico (azúl), como el de gasolina (negro) . <a name="fig:1"></a>
# ![image1.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Vuelta2_Ele.png?raw=true)
# ![image2.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Vuelta1_Gas.png?raw=true)

# %% [markdown]
# Cabe aclarar que estos mapas se realizan tomando los datos la latitud conntra la longitud medidos por el VBox. A partir de estos resultados parece que los datos del kart a gasolina son más precisos, pués la vuelta del kart eléctrico tuvo unos cambios bruscos de altitud que alteran su forma. Además se hace el análisis de velocidad comparando los valores alcanzados por el kart en la vuelta seleccionada ([figura 2](#fig:2)).

# %% [markdown]
# ###### Figura 2. Velocidades instantaneas medidas para cada kart, tanto el eléctrico (azúl), como el de gasolina (negro) . <a name="fig:2"></a>
# ![image3.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Velocidadvuelta2_Ele.png?raw=true)
# ![image4.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Velocidadvuelta1_Gas.png?raw=true)

# %% [markdown]
# Los rangos de velocidad alcanzados por cada kart varían entre 35-70 km/h para el kart eléctrico (que parece haberse detenido en algunos momentos) y 42-90 km/h para el kart a gasolino que se mantuvo siempre en movimiento.   Las aceleraciones alcanzadas ([figura 3](#fig:3)) pueden tomarse como un indicador de el tiempo que le podría tomar al kart llegar a su velocidad máxima o en últimas recorrer una mayor cantidad de la vuelta en menos timepo.

# %% [markdown]
# ###### Figura 3. Aceleración calculada para cada kart, tanto el eléctrico (azúl), como el de gasolina (negro) . <a name="fig:3"></a>
# ![image5.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Aceleracionvuelta2_Ele.png?raw=true)
# ![image6.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Aceleracionvuelta1_Gas.png?raw=true)

# %% [markdown]
# Como era de esperar, el kart a gasolina alcanza aceleraciones (tanto de arranque como de frenado) de mayor valor, lo que permite un mayor control del kart y alcanzar velocidades óptimas más rapido. La [tabla 1.](#tan:1) resume y compara los resultados obtenidos por cada kart.

# %% [markdown]
# | Parámetro                              | Eléctrico | Gasolina |
# |:---------------------------------:|-----------|----------|
# | Tiempo de vuelta [s]              | 136.25    | 54.31    |
# | Velocidad máxima alcanzada [km/h] | 69.51     | 90.97    |
# | Velocidad promedio [km/h]         | 30.88     | 65.18    |
# | Aceleración máxima [m/s^2]        | 2.23      | 3.51     |

# %% [markdown]
# De estos resultados se evidencia que el kart eléctrico se demora 2.5 veces más que el kart a gasolina, y en general los valores de velocidad y aceleración son menores lo que aumenta su tiempo de vuelta.

# %% [markdown]
# ## 3. Análisis de desempeño y comparación de momento par, potencia y velocidad de giro <a name="tercero"></a>

# %% [markdown]
# En la sección de [Anexos](#quinto) se enccuentran las funciones empleadas para calcular las variables mencionadas a continuación. Las fuerzas a las que se somete el kart y el comportamiento del sistema varia notablemente para cada caso.

# %% [markdown]
# ###### Figura 4. Desempeño de cada kart en la vuelta seleccionada, tanto el eléctrico (azúl), como el de gasolina (negro) . <a name="fig:4"></a>
# ![image7.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Comparaci%C3%B3n_arrastre.png?raw=true)
# ![image8.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Comparaci%C3%B3n_rodadura.png?raw=true)
# ![image9.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Comparaci%C3%B3n_tracci%C3%B3n.png?raw=true)

# %% [markdown]
# Los datos suministrados en la [figura 4](#fig:4) se dividen en tres gráficas dado que los valores de la fuerza de rodadura son tan pequeños comparados con el resto que no se notarían en una sola gráfica. En cuanto al arrastre que sufre el kart, se sabe que este esta relacionado directamente con la velocidad que lleva el kart, por lo tanto tiene sentido, que el kart a gasolina, que tiene una mayor velocidad, registre valores mayores de fuerza de arraste, llegando a un máximo de 3750N que es 1.74 veces mayor que el pico de máximo valor del kart eléctrico de 2150N. En cuanto a la fuerza de rodadura no se registran variaciones muy elevadas comparadas con el resto de parámetros evaluados, esta diferencia  es de solo 0.75N. Por últim se encontró que la diferencia entre los valores calculados de fuerza de tracción y la fuerza de arrastre no es muy grande por lo que se asume que gran parte de la fuerza de tracción se encarga de superar únicamente la fuerza de arrastre generada en el kart.

# %% [markdown]
# ###### Figura 5. Velocidad de giro, torque y potencia de cada kart en la vuelta seleccionada, tanto el eléctrico (azúl), como el de gasolina (negro) . <a name="fig:5"></a>
# ![image10.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Comparaci%C3%B3n_angular.png?raw=true)
# ![image11.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Comparaci%C3%B3n_torque.png?raw=true)
# ![image12.png](https://github.com/DiegoFelipeBryan/-Herramientas-Computacionales-IMEC3602/blob/master/Taller_3/output/Comparaci%C3%B3n_potencia.png?raw=true)

# %% [markdown]
# En la [figura 5](#fig:5)

# %% [markdown]
# ## 5. Anexos <a name="quinto"></a>

# %%
def accel(vx, ddt):
    return ndimage.gaussian_filter1d(vx, sigma=20, order=1, mode='wrap') / ddt

# %% [markdown]
# Archivo de kart eléctrico seleccionado

# %%
carpeta1 = 'data_electrico'
file1 = 'VBS__052.VBO'

# %% [markdown]
# Datos medidos por el VBox

# %%
kartelectric = load(carpeta1,file1)
tiempoele = kartelectric[0]
latitudele = kartelectric[1]
longitudele = kartelectric[2]
velocidadele = kartelectric[3]
alturaele = kartelectric[4]
velocidadvertele =  kartelectric[5]
tiempobaseele = kartelectric[6]
deltaele = kartelectric[7]

# %% [markdown]
# Gráfica de la primera vuelta seleccionada

# %%
nele1 = 3620
nele2 = 5520
lele1 = longitudele[nele1:nele2]
latele1 = latitudele[nele1:nele2]
plt.plot(lele1,latele1,'b')
plt.axis('off')
pylab.savefig(os.path.join(output_dir,'Vuelta1_Ele.png'), dpi=70)
plt.show()

# %% [markdown]
# Tiempo transcurrido en la primera vuelta seleccionada

# %%
tele1 = tiempoele[nele1:nele2] 
tiempovueltaele1 = tele1-tele1[0]
tiempototalele1 = tiempovueltaele1[-1]
tiempototalele1
# Out:
# 282.30000000000291

# %% [markdown]
# Gráfica de las velocidades registradas en la primera vuelta

# %%
vele1 = velocidadele[nele1:nele2]
plt.plot(tele1,vele1,'b')
xlabel('Tiempo [s]')
ylabel('Velocidad [km/h]')
pylab.savefig(os.path.join(output_dir,'Velocidadvuelta1_Ele.png'), dpi=70)
plt.grid()
plt.show()

# %% [markdown]
# Como hay un momento en el que el kart se detiene se revisa primero la velocidad en función del tiempo

# %%
plt.plot(tiempoele,velocidadele,'b')
xlabel('Tiempo [s]')
ylabel('Velocidad [km/h]')
pylab.savefig(os.path.join(output_dir,'VelocidadTotal_Ele.png'), dpi=70)
plt.grid()
plt.show()

# %% [markdown]
# Se eligen los datos un poco antes de 800 segundos donde el kart no paró

# %%
nele3 = 5120
nele4 = 7407
lele2 = longitudele[nele3:nele4]
latele2 = latitudele[nele3:nele4]
tele2 = tiempoele[nele3:nele4]
vele2 = velocidadele[nele3:nele4]
plt.plot(tele2,vele2,'b')
xlabel('Tiempo [s]')
ylabel('Velocidad [km/h]')
pylab.savefig(os.path.join(output_dir,'Velocidadvuelta2_Ele.png'), dpi=70)
plt.grid()
plt.show()

# %%
plt.plot(lele2,latele2,'b')
plt.axis('off')
pylab.savefig(os.path.join(output_dir,'Vuelta2_Ele.png'), dpi=70)
plt.grid()
plt.show()

# %%
tiempovueltaele2 = tele2-tele2[0]
tiempototalele2 = tiempovueltaele2[-1]

# %% [markdown]
# La aceleración en esta vuelta fue de

# %%
acelele = accel(vele2/3.6,deltaele)
plt.plot(tiempovueltaele2,acelele,'b')
xlabel('Tiempo [s]')
ylabel('Aceleración [$m/s^2$]')
pylab.savefig(os.path.join(output_dir,'Aceleracionvuelta2_Ele.png'), dpi=70)
plt.grid()
plt.show()

# %%
print(tiempototalele2,max(vele2),mean(vele2),max(acelele))
# Out:
# 136.25 69.51 30.8774639265 2.23027012327

# %% [markdown]
# Archivo del kart a gasolina seleccionado

# %%
carpeta2 = 'Data'
file2 = 'VBOX0020.VBO'

# %% [markdown]
# Datos medidos por el VBox

# %%
kartgaso = load(carpeta2,file2)
tiempogas = kartgaso[0]
latitudgas = kartgaso[1]
longitudgas = kartgaso[2]
velocidadgas = kartgaso[3]
alturagas = kartgaso[4]
velocidadvertgas =  kartgaso[5]
tiempobasegas = kartgaso[6]
deltagas = kartgaso[7]

# %% [markdown]
# Gráfica de la primera vuelta seleccionada

# %%
ngas1 = 3000
ngas2 = 8432
lgas = longitudgas[ngas1:ngas2]
latgas = latitudgas[ngas1:ngas2]
tgas = tiempogas[ngas1:ngas2]
vgas = velocidadgas[ngas1:ngas2]
plt.plot(lgas,latgas,'k')
plt.axis('off')
pylab.savefig(os.path.join(output_dir,'Vuelta1_Gas.png'), dpi=70)
plt.grid()
plt.show()

# %% [markdown]
# Tiempo transcurrido en la primera vuelta seleccionada

# %%
tiempovueltagas = tgas-tgas[0]
tiempototalgas = tiempovueltagas[-1]
tiempototalgas
# Out:
# 54.310000000004948

# %%
plt.plot(tgas,vgas,'k')
xlabel('Tiempo [s]')
ylabel('Velocidad [km/h]')
pylab.savefig(os.path.join(output_dir,'Velocidadvuelta1_Gas.png'), dpi=70)
plt.grid()
plt.show()

# %% [markdown]
# Para verificar que sea una un tiempo y velocidad óptimo se gráfican todos los datos de velocidad medidos

# %%
plt.plot(tiempogas,velocidadgas,'k')
xlabel('Tiempo [s]')
ylabel('Velocidad [km/h]')
pylab.savefig(os.path.join(output_dir,'VelocidadTotal1_Gas.png'), dpi=70)
plt.grid()
plt.show()

# %% [markdown]
# Como los datos seleccionados estan entre el rango de los 30 y 85 segundos se asume una selección adecuada de vuelta

# %%
acelgas = accel(vgas/3.6,deltagas)
plt.plot(tiempovueltagas,acelgas,'k')
xlabel('Tiempo [s]')
ylabel('Aceleración [$m/s^2$]')
pylab.savefig(os.path.join(output_dir,'Aceleracionvuelta1_Gas.png'), dpi=70)
plt.grid()
plt.show()

# %%
print(tiempototalgas,max(vgas),mean(vgas),max(acelgas))
# Out:
# 54.31 90.967 65.1811137703 3.51064557097

# %% [markdown]
# ### Funciones para encontrar comparar desempeño, momento par, potencia y velocidad de giro

# %% [markdown]
# Parámetros del kart eléctrico

# %%
dpl = 39 # Dientes plato
dpi = 11 # Dientes piñon 
n = dpl/dpi # Relación 
eta = 0.95 # Eficiencia en la transmisión

rt = 0.139 # Radio geométrico de la llanta [m] 
refe = 0.98*rt # Radio efectivo trasero [m]

rho = 1.1955 # Densidad del aire [kg/m^3]
dlld = 0.975 # Distancia entre llantas delanteras [m]
alpi = 0.88 # Altura del piloto sentado [m]
Af = dlld * alpi # Área frontal [m^2]
Ca = 0.89 # Coeficinete de arrastre




Im = 5.3E-3 # Inercia del motor eléctrico [kg^2]
mt = 1.43 # Masa llanta trasera[kg]
md = 1.2 # Masa llanta delantera [kg]
rd = 0.129 # Radio llanta delantera[m]
rrid = 0.0631 # Radio del rin delantero[m]
rrit = rrid # Radio del rin trasero[m]

mbant = 0.7*mt # Masa de la banda en la llanta trasera [kg]
mdisct = 0.3*mt #Masa del disco en la llanta trasera [kg]
mband = 0.7*mt # Masa de la banda en la llanta delantera [kg]
mdiscd = 0.3*mt # Masa del disco en la llanta delantera [kg]

Id = (mband*rd)+(mdiscd*(rd**2-rrid**2))/2 # Inercia de la llanta delantera [kg m^2]
It = (mbant*rt)+(mdisct*(rt**2-rrit**2))/2 # Inercia de la llanta trasera [kg m^2]

reje = 0.02 # Radio del eje de las llantas [m]
meje = 3.832 # Masa del eje de las llantas [kg]
Ieje = (meje*reje**2)/2 # Inercia del eje de las llantas [kg m^2]


mK = 152 # Masa del kart [kg]
mP = 62 # Masa del piloto [kg]
g = 9.81 # Aceleración gravitacional [m/s^2]
pesoK = mK*g  # Peso del kart [N]

# %% [raw]
# Parámetros del kart a gasolina

# %%
# Datos Llantas tractivas 
rll=0.139 # Radio geométrico de las llantas en traseras (m)
refc=0.98*rll # Radio efectivo llantas traseras (m)
rin=0.0631 #radio interno del neumático (m)

# Datos Transmisión
dp=11.0 # Dientes del piñon
dpl=87.0 # Dientes del plato
ng=dpl/dp # Relación de Transmisión
etaf=0.95 # Eficiencia de transmisión

# Datos eje llantas
reje=0.02 # Radio eje de las llantas (m)
meje=3.832 # Masa del eje (kg)

# Datos Kart general
masa=140.0 # masa del Kart con piloto(kg)
g=9.81 # Gravedad (m/s)
w=masa*g # peso del Kart (N)

# Datos Fuerzas de la fórmula de aceleración
rho=1.1955 # densidad del aire (kg/m^3)
dll=0.975 # Distancia entre ejes de llantas delanteras (m)
alj=0.88 # Altura con el piloto sentado en el kart (estatura 1.68 m) (m)
af=(dll*alj)/2 # Area Frontal Kart (m^2)
cd=0.89 # Coeficiente de Arrastre Kart
vw=0.0 # velocidad del viento (m/s)
theta=0.0 # Angulo carretera

# Inercias
ii=0.01 # Inercia motor de combustión 

mllt=1.43 # Masa llantas traseras (kg)
mlld=1.20 # Masa llantas delanteras (kg)
rlld=0.129 # Radio llantas delanteras (m)
rind=0.0631 # Radio rin llantas delanteras (m)
mbt=0.7*mllt # El porcentaje de la masa total que pesa la parte "banda" de la llanta trasera
mdt=0.3*mllt # El porcentaje de la masa total que pesa la parte "disco" de la llanta trasera
mbd=0.7*mlld # El porcentaje de la masa total que pesa la parte "banda" de la llanta delantera
mdd=0.3*mlld # El porcentaje de la masa total que pesa la parte "disco" de la llanta delantera
illd=(mbd*rlld)+(mdd*(rlld**2-rind**2))/2 # Inercia 1 llanta delantera (kg-m^2)
illt=(mbt*rll)+(mdt*(rll**2-rin**2))/2 # Inercia 1 llanta trasera (kg-m^2)

rpi=0.01525 # Radio Piñon (m)
rpla=0.10775 # Radio Plato (m)
rhoac=7850.0 # Densidad del Acero (kg/m^3)
bpi=0.01 # Ancho piñon (m)
bpla=0.01 # Ancho plato (m)
vpi= bpi*np.pi*rpi**2 # Volumen del piñon (m^3)
vpla=bpla*np.pi*rpla**2 # Volumen del plato (m^3)
mpi=rhoac*vpi # Masa del piñon (kg)
mpla=rhoac*vpla # Masa del plato (kg)
ig=((mpi*(rpi**2))/2)+((mpla*(rpla**2))/2) # Inercia de la transmisión (kg-m^2)

ieje=(meje*reje**2)/2 # Inercia del eje de las llantas (kg-m^2)

# Fuerzas Aceleración
# Resistencia a la rodadura
a=0.2036 # Distancia del centro de gravedad al eje de la llanta trasera (m)
l=1.0063 # Distancia de eje de las llantas traseras y delanteras (m)
h=0.0960 # Altura del centro de gravedad del kart con respecto al piso (m)

# %%
# Función de fuerza de arrastre
def arrastre (V):
    A = 0.5*rho*Af*Ca*V**2
    return A

# %%
# Función de fuerza de rodadura
def frodadura(vx,ax):
    wr=w*((a/l)+(ax/g*(h/l))) # fuerza vertical sobre las llantas tractivas
    fr=0.01*(1+(vx/100.0)) # Factor de rodadura la velocidad del kart debe estar en (km/h)
    return wr*fr

# %%
# Función de fuerza de tracción
def ftraccion(ax,Fw,Fr):
    return (masa*ax)+Fw+Fr

# %%
# Función de torque del motor
def torquemotor(ax,Ft,rela,imotor):
    return (Ft+(((imotor-ig)/(rela**2))+ieje+illd*2+illt*2)*(ax/(refc**2)))*(refc/(rela*etaf)) # Torque del motor (Nm)

# %%
# Función de velocidad de giro
def vangularmotor(vx,rela):
    return (vx*rela)/refc # (rad/s)

# %%
# Función de potencia
def potencia(omega,Tor):
    p = omega*Tor/1000
    return p

# %% [markdown]
# Análisis de desempeño

# %%
arrastreele = arrastre(vele2)
rodaduraele = frodadura(vele2,acelele)
tracele = ftraccion(acelele,arrastreele,rodaduraele)
arrastregas = arrastre(vgas)
rodaduragas = frodadura(vgas,acelgas)
tracgas = ftraccion(acelgas, arrastregas, rodaduragas)
plt.plot(tiempovueltaele2,rodaduraele,'b')
plt.plot(tiempovueltagas,rodaduragas,'k')
plt.axhline(y=5.5,color='k',linestyle='--')
plt.axhline(y=4.75,color='b',linestyle='--')
plt.annotate('5.5', xy = (80,5.6))
plt.annotate('4.75', xy = (80, 4.8),color='b')
xlabel('Tiempo [s]')
ylabel('Fuerza de rodadura [N]')
pylab.savefig(os.path.join(output_dir,'Comparación_rodadura.png'), dpi=70)
plt.grid()
plt.show()

# %%
plt.plot(tiempovueltaele2,arrastreele,'b')
plt.plot(tiempovueltagas,arrastregas,'k')
plt.axhline(y=3750,color='k',linestyle='--')
plt.axhline(y=2150,color='b',linestyle='--')
plt.annotate('3750', xy = (80,3790))
plt.annotate('2150', xy = (80, 2200),color='b')
xlabel('Tiempo [s]')
ylabel('Fuerza de arrastre [N]')
pylab.savefig(os.path.join(output_dir,'Comparación_arrastre.png'), dpi=70)
plt.grid()
plt.show()

# %%
plt.plot(tiempovueltaele2,tracele,'b')
plt.plot(tiempovueltagas,tracgas,'k')
plt.axhline(y=3800,color='k',linestyle='--')
plt.axhline(y=2150,color='b',linestyle='--')
plt.annotate('3800', xy = (80,3580))
plt.annotate('2150', xy = (80, 2200),color='b')
xlabel('Tiempo [s]')
ylabel('Fuerza de tracción [N]')
pylab.savefig(os.path.join(output_dir,'Comparación_tracción.png'), dpi=70)
plt.grid()
plt.show()

# %% [markdown]
# Comparación de torque

# %%
torqueele = torquemotor(acelele,tracele,n,Im)
torquegas = torquemotor(acelgas,tracgas,ng,ii)
plt.plot(tiempovueltaele2,torqueele,'b')
plt.plot(tiempovueltagas,torquegas,'k')
plt.axhline(y=69,color='k',linestyle='--')
plt.axhline(y=65,color='b',linestyle='--')
plt.annotate('69', xy = (80,71))
plt.annotate('65', xy = (90,59),color='b')
xlabel('Tiempo [s]')
ylabel('Momento par [Nm]')
pylab.savefig(os.path.join(output_dir,'Comparación_torque.png'), dpi=70)
plt.grid()
plt.show()

# %% [markdown]
# Comparación de velocidad angular

# %%
wele = vangularmotor(vele2,n)
wgas = vangularmotor(vgas,ng)
plt.plot(tiempovueltaele2,wele,'b')
plt.plot(tiempovueltagas,wgas,'k')
plt.axhline(y=5200,color='k',linestyle='--')
plt.axhline(y=1800,color='b',linestyle='--')
plt.annotate(5200 , xy = (68,4900))
plt.annotate(1800, xy = (68,1900),color='b')
xlabel('Tiempo [s]')
ylabel('Velocidad angular [rad/s]')
pylab.savefig(os.path.join(output_dir,'Comparación_angular.png'), dpi=70)
plt.grid()
plt.show()

# %% [markdown]
# Comparación potencia

# %%
potele = potencia(wele,torqueele)
potgas = potencia(wgas,torquegas)
plt.plot(tiempovueltaele2,potele,'b')
plt.plot(tiempovueltagas,potgas,'k')
plt.axhline(y=360,color='k',linestyle='--')
plt.axhline(y=150,color='b',linestyle='--')
plt.annotate(360 , xy = (68,360-20))
plt.annotate(150, xy = (68,150+10),color='b')
xlabel('Tiempo [s]')
ylabel('Potencia [kW]')
pylab.savefig(os.path.join(output_dir,'Comparación_potencia.png'), dpi=70)
plt.grid()
plt.show()

# %%
tiempototalele2/tiempototalgas
# Out:
# 2.5087460872765162

# %%
max(arrastreele)
# Out:
# 2205.4207496175854

# %%
max(tracele)
# Out:
# 2162.4688133355194

# %%
max(arrastregas)
# Out:
# 3777.1534084801178

# %%
max(tracgas)
# Out:
# 3800.819996382887
